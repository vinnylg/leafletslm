# %%
import logging
from time import sleep
from drugslm.scraper.selenium import webdriver_manager, get_firefox_options
from drugslm.utils.logging import get_log_path, setup_logging

log_file_path = get_log_path("0.2.selenium_test.ipynb")
setup_logging(log_file_path)

logger = logging.getLogger("jupyter")

log_file_path

# %%
logger.info("Teste")

# %%
def teste():
    logger.info("Teste2")

teste()

# %%
options = get_firefox_options()
ctx = webdriver_manager(options)
driver = ctx.__enter__()

# %%
driver.get("https://www.youtube.com")
sleep(10)

# %%
ctx.__exit__(None,None,None)

# %%
from drugslm.scraper.anvisa.index import process_category_pages

# %%
with webdriver_manager(options) as driver:
    process_category_pages(driver,1)
