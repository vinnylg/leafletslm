# %%
from ollama import Client

# %%
client = Client(host="http://ollama.lilith.hell")

messages = [
    {
        'role': 'system',
        'content': 'Você é um contador de histórias'
    }
]

response = client.chat(model="llama3.1:8B", messages=messages)
messages.append(response['message'])
print(response['message']['content'])

# %%
msg = "Me conte uma história aléatória"
messages.append({'role':'user','content':msg})
response = client.chat(model="llama3.1:8B", messages=messages)
messages.append(response['message'])
print(response['message']['content'])
# Out:
# Que prazer contar uma história!
#
# Havia uma vez, em uma pequena vila escondida entre as montanhas, um jovem chamado Kaito. Kaito era um menino excepcionalmente curioso e com uma imaginação fértil. Ele sempre se perguntava sobre o mundo além da vila e sonhava em explorar tudo o que existia lá fora.
#
# Um dia, enquanto caminhava pelo bosque à margem do rio que banhava a vila, Kaito encontrou um velho madeireiro sentado ao lado de uma árvore antiga. O homem, com olhos cansados mas cheios de sabedoria, perguntou a Kaito por que ele estava tão perdido em pensamentos.
#
# Kaito confessou seu desejo de explorar o mundo além da vila e descobrir os segredos do universo. O madeireiro, após uma pausa longa, disse algo que mudou para sempre a vida de Kaito:
#
# "O mundo é um livro imenso, escrito com letras de fogo e água. Cada página tem seu próprio segredo, mas é preciso saber onde procurar."
#
# ...
